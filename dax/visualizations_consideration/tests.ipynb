# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# Mean zero assumption

# %%
from dax.help_functions.get_dax_data import get_prepared_data

daxdata = get_prepared_data()
daxdata
# Out:
#                                   Close  LogRetLag1  LogRetLag2  LogRetLag3  \
# Date
# 2019-09-10 00:00:00+02:00  12268.709961    0.347914    0.629422    1.163586
# 2019-09-11 00:00:00+02:00  12359.070312    0.733812    1.081725    1.363234
# 2019-09-12 00:00:00+02:00  12410.250000    0.413251    1.147063    1.494977
# 2019-09-13 00:00:00+02:00  12468.530273    0.468515    0.881766    1.615578
# 2019-09-16 00:00:00+02:00  12380.309570   -0.710062   -0.241547    0.171704
# ...                                 ...         ...         ...         ...
# 2023-11-16 00:00:00+01:00  15786.610352    0.243797    1.096667    2.837245
# 2023-11-17 00:00:00+01:00  15919.160156    0.836129    1.079926    1.932796
# 2023-11-20 00:00:00+01:00  15901.330078   -0.112067    0.724062    0.967860
# 2023-11-21 00:00:00+01:00  15900.530273   -0.005030   -0.117097    0.719032
# 2023-11-22 00:00:00+01:00  15957.820312    0.359655    0.354625    0.242559
#
#                            LogRetLag4  LogRetLag5
# Date
# 2019-09-10 00:00:00+02:00    2.006097    2.960150
# 2019-09-11 00:00:00+02:00    1.897398    2.739909
# 2019-09-12 00:00:00+02:00    1.776485    2.310649
# 2019-09-13 00:00:00+02:00    1.963491    2.245000
# 2019-09-16 00:00:00+02:00    0.905516    1.253429
# ...                               ...         ...
# 2023-11-16 00:00:00+01:00    3.560679    2.788120
# 2023-11-17 00:00:00+01:00    3.673374    4.396808
# 2023-11-20 00:00:00+01:00    1.820729    3.561307
# 2023-11-21 00:00:00+01:00    0.962830    1.815699
# 2023-11-22 00:00:00+01:00    1.078688    1.322485
#
# [1072 rows x 6 columns]

# %%
t_statistic, p_value = stats.ttest_1samp(daxdata[['LogRetLag1']], popmean=0)
t_statistic
p_value
# Out:
# array([0.55907563])
