# %%
import pandas as pd
import numpy as np

from dax.models.time_series_models.garch11_t import get_garch_11_t
from dax.models.baseline import get_dax_forecasts_baseline

proportion=[0.5, 0.5]

garch_t_forecasts = get_garch_11_t()
baseline_forecasts = get_dax_forecasts_baseline()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 18782.929938468144
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 2689.396426270799
# Iteration:      3,   Func. Count:     21,   Neg. LLF: 2872.2883131688286
# Iteration:      4,   Func. Count:     27,   Neg. LLF: 2512.040632240171
# Iteration:      5,   Func. Count:     33,   Neg. LLF: 1633.5781288697367
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 1655.1444975931322
# Iteration:      7,   Func. Count:     45,   Neg. LLF: 1631.0196478993641
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 1630.9670678627122
# Iteration:      9,   Func. Count:     55,   Neg. LLF: 1630.9531726086493
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1630.9463208455136
# Iteration:     11,   Func. Count:     65,   Neg. LLF: 1630.9462284599172
# Iteration:     12,   Func. Count:     70,   Neg. LLF: 1630.9462256026227
# Iteration:     13,   Func. Count:     74,   Neg. LLF: 1630.9462256026231
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1630.9462256026227
#             Iterations: 13
#             Function evaluations: 74
#             Gradient evaluations: 13
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2907.5731482996516
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 2260.229814894826
# Iteration:      3,   Func. Count:     24,   Neg. LLF: 2076.0970502299547
# Iteration:      4,   Func. Count:     30,   Neg. LLF: 1970.1094200142936
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 1969.5566638912671
# Iteration:      6,   Func. Count:     40,   Neg. LLF: 1969.4027713262717
# Iteration:      7,   Func. Count:     45,   Neg. LLF: 1969.3079311511885
# Iteration:      8,   Func. Count:     50,   Neg. LLF: 1969.2847062219091
# Iteration:      9,   Func. Count:     55,   Neg. LLF: 1969.2812330605652
# Iteration:     10,   Func. Count:     60,   Neg. LLF: 1969.2802584982787
# Iteration:     11,   Func. Count:     65,   Neg. LLF: 1969.2799278458583
# Iteration:     12,   Func. Count:     70,   Neg. LLF: 1969.2798707137863
# Iteration:     13,   Func. Count:     75,   Neg. LLF: 1969.2798626320623
# Iteration:     14,   Func. Count:     80,   Neg. LLF: 1969.2798620642761
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 1969.2798620642761
#             Iterations: 14
#             Function evaluations: 80
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 3032.8268539110545
# Iteration:      2,   Func. Count:     16,   Neg. LLF: 2232.8181654765485
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 2501.102302185705
# Iteration:      4,   Func. Count:     28,   Neg. LLF: 2193.0021170251225
# Iteration:      5,   Func. Count:     34,   Neg. LLF: 2154.990429629785
# Iteration:      6,   Func. Count:     39,   Neg. LLF: 2153.9391983971145
# Iteration:      7,   Func. Count:     44,   Neg. LLF: 2153.660014692801
# Iteration:      8,   Func. Count:     49,   Neg. LLF: 2153.4849207072793
# Iteration:      9,   Func. Count:     54,   Neg. LLF: 2153.4388093923208
# Iteration:     10,   Func. Count:     59,   Neg. LLF: 2153.432148333484
# Iteration:     11,   Func. Count:     64,   Neg. LLF: 2153.4307562638696
# Iteration:     12,   Func. Count:     69,   Neg. LLF: 2153.4303064641435
# Iteration:     13,   Func. Count:     74,   Neg. LLF: 2153.4302715384147
# Iteration:     14,   Func. Count:     79,   Neg. LLF: 2153.4302701709166
# Iteration:     15,   Func. Count:     83,   Neg. LLF: 2153.4302701709157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2153.4302701709166
#             Iterations: 15
#             Function evaluations: 83
#             Gradient evaluations: 15
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 3928.564876472225
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 2257.0176637424966
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 2800.4278514330354
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 2294.927090811735
# Iteration:      5,   Func. Count:     31,   Neg. LLF: 2236.183283174286
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 2236.1319993081543
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 2235.916947791331
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 2235.773948182082
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 2235.7115028617236
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 2235.6702218431446
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 2235.6618735964034
# Iteration:     12,   Func. Count:     66,   Neg. LLF: 2235.6617464180326
# Iteration:     13,   Func. Count:     71,   Neg. LLF: 2235.6617420915827
# Iteration:     14,   Func. Count:     75,   Neg. LLF: 2235.661742091584
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2235.6617420915827
#             Iterations: 14
#             Function evaluations: 75
#             Gradient evaluations: 14
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 67190.51896824589
# Iteration:      2,   Func. Count:     13,   Neg. LLF: 2355.3578386803015
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 2376.0629792676677
# Iteration:      4,   Func. Count:     26,   Neg. LLF: 2305.81131795725
# Iteration:      5,   Func. Count:     31,   Neg. LLF: 2304.471138694958
# Iteration:      6,   Func. Count:     36,   Neg. LLF: 2303.810208440775
# Iteration:      7,   Func. Count:     41,   Neg. LLF: 2303.668819536361
# Iteration:      8,   Func. Count:     46,   Neg. LLF: 2303.6548397188444
# Iteration:      9,   Func. Count:     51,   Neg. LLF: 2303.6541061027665
# Iteration:     10,   Func. Count:     56,   Neg. LLF: 2303.6530586175713
# Iteration:     11,   Func. Count:     61,   Neg. LLF: 2303.6506361170023
# Iteration:     12,   Func. Count:     66,   Neg. LLF: 2303.648743811512
# Iteration:     13,   Func. Count:     71,   Neg. LLF: 2303.6474450751807
# Iteration:     14,   Func. Count:     76,   Neg. LLF: 2303.647354138898
# Iteration:     15,   Func. Count:     81,   Neg. LLF: 2303.6473441434855
# Iteration:     16,   Func. Count:     85,   Neg. LLF: 2303.6473441434837
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2303.6473441434855
#             Iterations: 16
#             Function evaluations: 85
#             Gradient evaluations: 16

# %%
garch_t_forecasts
# Out:
#            forecast_date target horizon  ...          q0.5     q0.75    q0.975
# date_time                                ...
# 2023-11-23    2023-11-22    DAX   1 day  ...  6.169109e-17  0.647091  2.425570
# 2023-11-24    2023-11-22    DAX   2 day  ...  7.964734e-17  0.823442  2.738035
# 2023-11-27    2023-11-22    DAX   5 day  ...  1.133115e-16  1.175122  4.007228
# 2023-11-28    2023-11-22    DAX   6 day  ...  1.486406e-16  1.530543  4.927023
# 2023-11-29    2023-11-22    DAX   7 day  ...  1.761963e-16  1.801978  5.499730
#
# [5 rows x 8 columns]

# %%
baseline_forecasts
# Out:
#                           forecast_date target  ...     q0.75    q0.975
# 2023-11-27 00:00:00+01:00    2023-11-24    DAX  ...  0.718274  2.719772
# 2023-11-28 00:00:00+01:00    2023-11-24    DAX  ...  0.987420  3.570492
# 2023-11-29 00:00:00+01:00    2023-11-24    DAX  ...  1.224285  4.628697
# 2023-11-30 00:00:00+01:00    2023-11-24    DAX  ...  1.443441  5.367396
# 2023-12-01 00:00:00+01:00    2023-11-24    DAX  ...  1.594461  6.259934
#
# [5 rows x 8 columns]

# %%
# Out:
#            forecast_date target horizon  ...      q0.5     q0.75    q0.975
# date_time                                ...
# 2023-11-23    2023-11-22    DAX   1 day  ...  0.033557  0.682682  2.572671
# 2023-11-24    2023-11-22    DAX   2 day  ...  0.040133  0.905431  3.154264
# 2023-11-27    2023-11-22    DAX   5 day  ...  0.082107  1.199703  4.317962
# 2023-11-28    2023-11-22    DAX   6 day  ...  0.100559  1.486992  5.147210
# 2023-11-29    2023-11-22    DAX   7 day  ...  0.169184  1.698220  5.879832
#
# [5 rows x 8 columns]
